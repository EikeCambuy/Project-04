# %%
import spotipy
import pandas as pd 
from spotipy.oauth2 import SpotifyClientCredentials
CLIENT_ID = "4109b2d9f5014671863bb2df1d1fbdd3"
CLIENT_SECRET = "5cb719fae80c4191a9c0b288f51bfe50"
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="ALpc220918",
                               db="spotify"))
#Initialize SpotiPy with user credentials


def spotify():
    sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                            client_secret=CLIENT_SECRET),requests_timeout=30)
                                                        
    df = pd.read_csv("/Users/arturcabral/Documents/Ironhack/Quests/Project-04/spotify_data.csv")
    df = df.drop_duplicates(subset="artist_name")
    artist = [artist for artist in df["artist_name"]]
    top_art = [sp.search(q=x, limit=1) for x in artist]
    t = 0
    top_artist_id = []
    for y in artist:
        artist_id = top_art[t]["tracks"]["items"][0]["artists"][0]["id"]
        top_artist_id.append(artist_id)
        t+=1  
    df_final = pd.DataFrame(top_artist_id, artist)
    df_final.to_csv("spotify_art_id_FINAL.csv")

# %%
spotify()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 spotify()
#
# Cell In[5], line 16, in spotify()
#      14 df = df.drop_duplicates(subset="artist_name")
#      15 artist = [artist for artist in df["artist_name"]]
# ---> 16 top_art = [sp.search(q=x, limit=1) for x in artist]
#      17 t = 0
#      18 top_artist_id = []
#
# Cell In[5], line 16, in <listcomp>(.0)
#      14 df = df.drop_duplicates(subset="artist_name")
#      15 artist = [artist for artist in df["artist_name"]]
# ---> 16 top_art = [sp.search(q=x, limit=1) for x in artist]
#      17 t = 0
#      18 top_artist_id = []
#
# File ~/anaconda3/lib/python3.11/site-packages/spotipy/client.py:587, in Spotify.search(self, q, limit, offset, type, market)
#     572 def search(self, q, limit=10, offset=0, type="track", market=None):
#     573     """ searches for an item
#     574
# ...

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                        client_secret=CLIENT_SECRET),requests_timeout=30)
                                                    
df = pd.read_csv("/Users/arturcabral/Documents/Ironhack/Quests/Project-04/spotify_data.csv")
df = df.drop_duplicates(subset="artist_name")
artist = [artist for artist in df["artist_name"]]
# top_art = [sp.search(q=x, limit=1) for x in artist]
# t = 0
# top_artist_id = []
# for y in artist:
#     artist_id = top_art[t]["tracks"]["items"][0]["artists"][0]["id"]
#     top_artist_id.append(artist_id)
#     t+=1  
# df_final = pd.DataFrame(top_artist_id, artist)
# df_final.to_csv("spotify_art_id_FINAL.csv")
len(artist)

# %%
df = pd.read_csv("/Users/arturcabral/Documents/Ironhack/Quests/Project-04/spotify_data.csv")

# %%
df.to_sql('book_details', con = engine, if_exists = 'append')
# Out:
# 1159764

# %%
df.dropna(inplace=True)
df.to_csv("spotify_clean.csv")

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# year                0
# genre               0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
df[160:170]
# Out:
#      Unnamed: 0        artist_name                track_name  \
# 160         160         Tyler Ward  We Found Love - Acoustic
# 161         161       Mark Lanegan          Ode to Sad Disco
# 162         162                AJJ              Lady Liberty
# 163         163                AJJ        Lookin' for a Love
# 164         164    Hannah Trigwell                Hallelujah
# 165         165    Eric Hutchinson                 Best Days
# 166         166    Eric Hutchinson         The People I Know
# 167         167     Steve Petrunak           White Christmas
# 168         168        Scars On 45             Heart on Fire
# 169         169  Ingrid Michaelson                      Fire
#
#                    track_id  popularity  year     genre  danceability  energy  \
# 160  5uXMRPK76nEjSAubcgpL5Y          31  2012  acoustic         0.525   0.166
# 161  0XQQV21AQBskS6BFRL4k5h          34  2012  acoustic         0.408   0.870
# ...
